# %% [markdown]
# <a href="https://colab.research.google.com/github/pixel82004/AI-AGENTS-INTRO-AI/blob/main/Assigment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Option 2: Uploading via Git Command Line
# To push files directly to GitHub from Colab, you need to set up your GitHub credentials. Run the cell below to configure your Git identity and push your notebook. Make sure to set your personal access token (PAT) in Colab Secrets as `GITHUB_TOKEN`.

# %%
# Import library to access secrets securely
from google.colab import userdata
import os

# Retrieve your GitHub Username and Personal Access Token (PAT) from Colab Secrets
# (Add these keys in the left sidebar key icon 🔑)
username = "YOUR_GITHUB_USERNAME"
repo_name = "YOUR_REPOSITORY_NAME"
token = userdata.get('GITHUB_TOKEN') # Save your token under name GITHUB_TOKEN

# Configure global Git settings
# !git config --global user.name "Your Name"
# !git config --global user.email "your_email@example.com"

# Initialize, commit, and push
# Note: This is an example setup. Adjust paths as needed.
# !git init
# !git add .
# !git commit -m "Upload notebook from Google Colab"
# !git remote add origin https://{token}@github.com/{username}/{repo_name}.git
# !git branch -M main
# !git push -u origin main
